# %% [markdown]
# **Упражнение 1**

# %%
import numpy as np

# %%
x = 1

# %%
y = np.log(1 / np.exp(np.sin(x) + 1) / (5/4 + x**15)) / np.log(1 + x**2)
# Out:
# <ipython-input-53-f2026bdfb3a1>:1: RuntimeWarning: invalid value encountered in log
#   y = np.log(1 / np.exp(np.sin(x) + 1) / (5/4 + x**15)) / np.log(1 + x**2)
# <ipython-input-53-f2026bdfb3a1>:1: RuntimeWarning: divide by zero encountered in true_divide
#   y = np.log(1 / np.exp(np.sin(x) + 1) / (5/4 + x**15)) / np.log(1 + x**2)

# %% [markdown]
# **Построение графиков**

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-10, 10.01, 0.01)
plt.plot(x, x**2)
plt.show()

# %%
x = np.arange(-10, 10.01, 0.01)
plt.plot(x, np.sin(x), x, np.cos(x), x, -x)
plt.show()

# %%
x = np.arange(-10, 10.01, 0.01)
plt.plot(x, np.sin(x), x, np.cos(x), x, -x)
plt.xlabel(r'$x$')
plt.ylabel(r'$f(x)$')
plt.title(r'$f_1(x)=\sin(x),\ f_2(x)=\cos(x),\ f_3(x)=-x$')
plt.grid(True)
plt.show()

# %%
x = np.arange(-10, 10.01, 0.01)
plt.figure(figsize=(10, 5))
plt.plot(x, np.sin(x), label=r'$f_1(x)=\sin(x)$')
plt.plot(x, np.cos(x), label=r'$f_2(x)=\cos(x)$')
plt.plot(x, -x, label=r'$f_3(x)=-x$')
plt.xlabel(r'$x$', fontsize=14)
plt.ylabel(r'$f(x)$', fontsize=14)
plt.grid(True)
plt.legend(loc='best', fontsize=12)
plt.savefig('figure_with_legend.png')
plt.show()

# %%
x = np.arange(-10, 10.01, 0.01)
t = np.arange(-10, 11, 1)

#subplot 1
sp = plt.subplot(221)
plt.plot(x, np.sin(x))
plt.title(r'$\sin(x)$')
plt.grid(True)

#subplot 2
sp = plt.subplot(222)
plt.plot(x, np.cos(x), 'g')
plt.axis('equal')
plt.grid(True)
plt.title(r'$\cos(x)$')

#subplot 3
sp = plt.subplot(223)
plt.plot(x, x**2, t, t**2, 'ro')
plt.title(r'$x^2$')

#subplot 4
sp = plt.subplot(224)
plt.plot(x, x)
sp.spines['left'].set_position('center')
sp.spines['bottom'].set_position('center')
plt.title(r'$x$')

plt.show()

# %%
plt.subplot(111, polar=True)
phi = np.arange(0, 2*np.pi, 0.01)
rho = 2*phi
plt.plot(phi, rho, lw=2)
plt.show()

# %%
t = np.arange(0, 2*np.pi, 0.01)
r = 4
plt.plot(r*np.sin(t), r*np.cos(t), lw=3)
plt.axis('equal')
plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np
ax = axes3d.Axes3D(plt.figure())
i = np.arange(-1, 1, 0.01)
X, Y = np.meshgrid(i, i)
Z = X**2 - Y**2
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)
plt.show()
# Out:
# <ipython-input-23-3293c4a9d026>:4: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = axes3d.Axes3D(plt.figure())

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)
# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=True, facecolor='g', alpha=0.75)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .035, r'$\mu=100,\ \sigma=15$')
plt.text(50, .030, r'$\varphi_{\mu,\sigma^2}(x) = \frac{1}{\sigma\sqrt{2\pi}} \,e^{ -\frac{(x- \mu)^2}{2\sigma^2}} = \frac{1}{\sigma} \varphi\left(\frac{x - \mu}{\sigma}\right),\quad x\in\mathbb{R}$', fontsize=15, color='red')
plt.axis([40, 160, 0, 0.04])
plt.grid(True)
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
# равномерно распределённые значения от 0 до 5, с шагом 0.2
t = np.arange(0., 5., 0.2)

# красные чёрточки, синие квадраты и зелёные треугольники
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
data = [33, 25, 20, 12, 10]
plt.figure(num=1, figsize=(6, 6))
plt.axes(aspect=1)
plt.title('Plot 3', size=14)
plt.pie(data, labels=('Group 1', 'Group 2', 'Group 3', 'Group 4', 'Group 5'))
plt.show()

# %%
objects = ('A', 'B', 'C', 'D', 'E', 'F')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Value')
plt.title('Bar title')

plt.show()

# %%
import pylab
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

def makeData():
        x = np.arange(-10, 10, 0.1)
        y = np.arange(-10, 10, 0.1)
        xgrid, ygrid = np.meshgrid(x, y)
        zgrid = np.sin(xgrid)*np.sin(ygrid)/(xgrid*ygrid)
        return xgrid, ygrid, zgrid

x, y, z = makeData()

fig = pylab.figure()
axes = Axes3D(fig)
axes.plot_surface(x, y, z, rstride=4, cstride=4, cmap=cm.jet)
pylab.show()
# Out:
# <ipython-input-41-9db0af3f05b8>:15: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   axes = Axes3D(fig)

# %% [markdown]
# **Упражнение 2**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-3, 4, 0.01)
y = x**2 - x - 6
plt.plot(x, y)
plt.grid(True)
plt.show()

# %% [markdown]
# **Упражнение 3**

# %%
x = np.arange(-10, 10, 0.01)
y = np.log((x**2 + 1)*np.exp(-np.abs(x)/10)) / np.log(1 + np.tan(1/(1 + np.sin(x)**2)))
plt.plot(x, y)
plt.grid(True)
plt.show()

# %% [markdown]
# **Упражнение 4**

# %%
x = np.arange(-10, 10, 0.01)
f = input()
y = eval(f)
with plt.xkcd():
    plt.plot(x, y)
    plt.grid(True)
    plt.show()
# Out:
# x**2

# %% [markdown]
# **Отображение погрешностей**

# %%
x = [1, 2, 3, 4, 5]
y = [0.99, 0.49, 0.35, 0.253, 0.18]
plt.errorbar(x, y, xerr=0.05, yerr=0.07)
plt.grid()
plt.show()

# %%
x = np.arange(0, 10, 0.01)
plt.plot(x, x**2, label=r'$f = x^2$')
plt.scatter(x, x**2 + np.random.randn(len(x))*x, s=0.3)
plt.fill_between(x, 1.3*x**2, 0.7*x**2, alpha=0.3)
plt.legend(loc='best')
plt.savefig('figure_fill_between.png')
plt.show()

# %%
x = [1, 2, 3, 4, 5, 6]
y = [1, 1.42, 1.76, 2, 2.24, 2.5]
p, v = np.polyfit(x, y, deg=1, cov=True)

# %%
p_f = np.poly1d(p)
p_f(x)
# Out:
# array([1.09142857, 1.38285714, 1.67428571, 1.96571429, 2.25714286,
#        2.54857143])

# %%
plt.plot(x, y, x, p_f(x))
plt.show()

# %%
a = 3
b = 0.5
n = 14
x = np.arange(-2, 2, 0.01)
w = np.array([])
for x_n in x:
    w_i = 0
    for i in range(n):
        w_i += b**i * np.cos(a**n * np.pi * x_n)
    w = np.append(w, w_i)
    
plt.plot(x, w)
plt.grid(True)
plt.show()

# %%
import numpy as np
from math import pi, cos, log
 
def power(a, n):
    return (1 if n == 0
            else power(a * a, n // 2) if n % 2 == 0
            else a * power(a, n - 1))
 
x_data = np.arange(-2, 2.01, 0.01)
n = 100
b = 0.5
eps = 1e-4
print('b^n = {:5.3e}'.format(power(b,n)))
m = round(log(eps) / log(b)) + 1
print('достаточное количество членов ряда : ',m)
n = m
a = 3
y_data = np.array([])
for x in x_data:
    y = 0
    for i in range(n):
        ai = power(a,i) * x * pi
        bi = power(b,i)    
        y += cos(ai)*bi
    y_data = np.append(y_data, y)
# Out:
# b^n = 7.889e-31
# достаточное количество членов ряда :  14

# %%
plt.plot(x_data, y_data)
plt.grid(True)
plt.show()
